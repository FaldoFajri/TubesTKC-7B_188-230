# %%
# !wget https://ribsandburgers.com/au/wp-content/uploads/2019/03/2-angus-bacon-and-cheese.jpg
# Out:
# --2021-11-10 07:46:21--  https://ribsandburgers.com/au/wp-content/uploads/2019/03/2-angus-bacon-and-cheese.jpg
# Resolving ribsandburgers.com (ribsandburgers.com)... 103.242.49.242
# Connecting to ribsandburgers.com (ribsandburgers.com)|103.242.49.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58178 (57K) [image/jpeg]
# Saving to: ‘2-angus-bacon-and-cheese.jpg’
#
# 2-angus-bacon-and-c 100%[===================>]  56.81K   288KB/s    in 0.2s
#
# 2021-11-10 07:46:22 (288 KB/s) - ‘2-angus-bacon-and-cheese.jpg’ saved [58178/58178]

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
    "image": "/content/2-angus-bacon-and-cheese.jpg"
}

# %%
# load the image, convert it to grayscale, and blur it slightly
image = cv2.imread(args["image"])
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# show the original and blurred images
plt_imshow("Original", image)
plt_imshow("Blurred", blurred)

# %%
# compute a "wide", "mid-range", and "tight" threshold for the edges
# using the Canny edge detector
wide = cv2.Canny(blurred, 10, 200)
mid = cv2.Canny(blurred, 30, 150)
tight = cv2.Canny(blurred, 240, 250)

# show the output Canny edge maps
plt_imshow("Wide Edge Map", wide)
plt_imshow("Mid Edge Map", mid)
plt_imshow("Tight Edge Map", tight)
